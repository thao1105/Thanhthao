# %% [markdown]
# <a href="https://colab.research.google.com/github/thao1105/Thanhthao/blob/main/Thanh_Th%E1%BA%A3o_AIK3_b%C3%A0i_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1.1

# %% [markdown]
# ![Bài 1.1 (6).png](data:image/png;base64,...)

# %%
n=abs(int(input("Nhập vào số n: ")))
s=0
for i in range (0, n+1):
  s=s+i
print("Tổng của 1 đến",n," là:",s)
# Out:
# Nhập vào số n: 4
# Tổng của 1 đến 4  là: 10

# %% [markdown]
# Bài 1.2

# %% [markdown]
# ![Bài 2.2.3 (5).png](data:image/png;base64,...)

# %%
n= (int(input('Nhập vào một số bất kì: ')))
s = 0
for i in range(1,n+1,2):
     s=s+i
     print(i)
print("Tổng các số lẻ từ 1 đến ",n," là:", s)
# Out:
# Nhập vào một số bất kì: 7
# 1
# 3
# 5
# 7
# Tổng các số lẻ từ 1 đến  7  là: 16

# %% [markdown]
# Bài 1.3

# %% [markdown]
# ![Bài 2.2.3 (5).png](data:image/png;base64,...)

# %%
N=abs(int(input("Nhập vào một số bất kì: ")))
s=0
for i in range(2,N+1,2) :
    s=s+i
print("Tổng các số chẵn từ 1 đến ",N," là:",s)
# Out:
# Nhập vào một số bất kì: 4
# Tổng các số chẵn từ 1 đến  4  là: 6

# %% [markdown]
# Bài 1.4

# %% [markdown]
# ![Bài 1.4 drawio.png](data:image/png;base64,...)

# %%
from math import log 
n = abs(int(input("Nhập vào số nguyên: ")))
s = 0
for i in range (1,n+1):
  s = s + log(i)
  print("Tổng của 1 đến ",n,"là:",s)
# Out:
# Nhập vào số nguyên: 5
# Tổng của 1 đến  5 là: 0.0
# Tổng của 1 đến  5 là: 0.6931471805599453
# Tổng của 1 đến  5 là: 1.791759469228055
# Tổng của 1 đến  5 là: 3.1780538303479453
# Tổng của 1 đến  5 là: 4.787491742782046

# %% [markdown]
# Bài 1.5

# %% [markdown]
# ![Bài 1.4 drawio (1).png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập vào số nguyên: ")))
s = 1 
for i in range (1,n):
  i = i+1 
  s = s + 1/i 
  print(i)
print("Tổng của 1 đến ",n," là:",s)
# Out:
# Nhập vào số nguyên: 5
# 2
# 3
# 4
# 5
# Tổng của 1 đến  5  là: 2.283333333333333

# %% [markdown]
# Bài 2.1 :
# Tính giai thừa của số n nguyên dương, n! = 1 × 2 × 3 × ... × n = ∏ i

# %% [markdown]
# ![Bài 2.1 (5).png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập một số bất kì ")))
s = 1
for i in range (1,n+1):
 s = s*i 
 print(i)
print("Giai thừa của ",n," là:",s)
# Out:
# Nhập một số bất kì 5
# 1
# 2
# 3
# 4
# 5
# Giai thừa của  5  là: 120

# %% [markdown]
# 2.2 P =
# 1
# n!
# , với n ∈ N và n > 0

# %% [markdown]
# ![Bài 2.2.2.png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập một số bất kỳ: ")))
s = 1 
for i in range(1,n+1):
  s = s*i
  P=1/s
  print(i)
print("Giai thừa của ",n," là:",P)
# Out:
# Nhập một số bất kỳ: 5
# 1
# 2
# 3
# 4
# 5
# Giai thừa của  5  là: 0.008333333333333333

# %% [markdown]
# 2.3. P = 1 × 3 × 5 × ... × n, với n ∈ N và n là số lẻ

# %% [markdown]
# ![Bài 2.2.3 (3).png](data:image/png;base64,...)

# %%
n = abs(int(input("nhập vào số nguyên ")))
s = 1
for i in range(1,n+1,2):
      s=s*i
print("Tích các số lẻ từ 1 đến ",n," là:",s)
# Out:
# nhập vào số nguyên 7
# 1
# 3
# 5
# 7
# Tích các số lẻ từ 1 đến  7  là: 105

# %% [markdown]
# 2.4.P = 2 × 4 × 6 × ... × n, với n ∈ N và n là số chẵn

# %% [markdown]
# ![Bài 2.2.3 (3).png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập một số nguyên :")))
s = 1
for i in range(2,n+1,2):
  s = s * i
print ("Tích các số chẳn từ 1 đến ",n," là:",s)
# Out:
# Nhập một số nguyên :8
# Tích các số chẳn từ 1 đến  8  là: 384
