# %% [markdown]
# <a href="https://colab.research.google.com/github/thao1105/Thanhthao/blob/main/Thanh_Th%E1%BA%A3o_AIK3_B%C3%A0i_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1.1

# %% [markdown]
# ![Bài 4.1 .png](data:image/png;base64,...)

# %%
n = int(input("Nhập vào số nguyên "))
s = 0
i = 1
while i <= n:
     s = s + i
     i = i + 1
print("Tổng các số lẻ từ 0 đến ",n," là:",s)
# Out:
# Nhập vào số nguyên 5
# Tổng các số lẻ từ 0 đến  5  là: 15

# %% [markdown]
# Bài 1.2

# %% [markdown]
# ![Bài 4.2.png](data:image/png;base64,...)

# %%
n = int(input("Nhập vào số nguyên: "))
s = 0
i = 1
while i <= n: 
    s = s + i 
    i = i + 2
print("Tổng các số lẻ từ 0 đến ",n," là:",s)
# Out:
# Nhập vào số nguyên: 9
# Tổng các số lẻ từ 0 đến  9  là: 25

# %% [markdown]
# Bài 1.3

# %% [markdown]
# ![Bài 4.3.png](data:image/png;base64,...)

# %%
 n = int(input("Nhập vào số nguyên: "))
 i = 0
 s = 0 
 while i <= n: 
    s = s + i 
    i = i + 2
 print("Tổng các số chẵn từ 0 đến ",n," là:",s)
# Out:
# Nhập vào số nguyên: 8
# Tổng các số chẵn từ 0 đến  8  là: 20

# %% [markdown]
# Bài 1.4

# %% [markdown]
# ![Bài 4.4.png](data:image/png;base64,...)

# %%
from math import log 
n = abs(int(input("Nhập vào số nguyên ")))
i = 1
s = log(1)
while n >= i:
 s = s + log(i)
 i = i + 1 
print(s)
# Out:
# Nhập vào số nguyên 5
# 4.787491742782046

# %% [markdown]
# Bài 1.5

# %% [markdown]
# ![Bài 4.5.png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập vào số nguyên ")))
s = 0
i = 1 
while n >= i:
  s = s + (1/i)
  i = i + 1  
print(s)
# Out:
# Nhập vào số nguyên 4
# 2.083333333333333

# %% [markdown]
# Bài 2.1

# %% [markdown]
# ![Bài 2.1 (3).png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập vào số nguyên ")))
s = 1
i = 1
while i <= n: 
  s = s * i 
  i = i + 1 
print("Giai thừa của ",n," là:",s)
# Out:
# Nhập vào số nguyên 4
# Giai thừa của  4  là: 24

# %% [markdown]
# Bài 2.2

# %% [markdown]
# ![Bài 2.4 (3).png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập vào số nguyên ")))
s = 1 
i = 1
while n >= i: 
    s = s*(1/i)
    i = i + 1 
print("P =",s)
# Out:
# Nhập vào số nguyên 4
# P = 0.041666666666666664

# %% [markdown]
# Bài 2.3

# %% [markdown]
# ![Bài 2.3 (1).png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập vào số nguyên ")))
s = 1 
i = 1 
while i <= n:
    s = s * i 
    i = i + 2 
print(s)
# Out:
# Nhập vào số nguyên 7
# 105

# %% [markdown]
# Bài 2.4

# %% [markdown]
# ![Bài 2.4 (2).png](data:image/png;base64,...)

# %%
n = abs(int(input("Nhập vào một số nguyên ")))
s = 1
i = 2
while i <= n:
     s = s *i 
     i = i + 2
print(s)
# Out:
# Nhập vào một số nguyên 8
# 384
